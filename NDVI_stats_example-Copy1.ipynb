# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# %run stats_app.py -n 149.002/149.252 -l -35.770/-35.1 -i PERCENTILE_10 -s 2010-01-01 -e 2015-12-03 -z LANDSAT_5,LANDSAT_7,LANDSAT_8 -q WINTER -b NDVI -p 2
# Out:
# arguments accepted start end lon lat epoch season interpolation stats masks band dataset sat 2010-01-01 2015-12-03 149.002/149.252 -35.770/-35.1 2 WINTER nearest PERCENTILE_10 PQ_MASK_CLEAR_ELB NDVI nbar LANDSAT_5,LANDSAT_7,LANDSAT_8
# gettting epochs
# myStats initialised
# threadID 1
# myStats initialised
# threadID 2
# myStats initialised
# threadID 3
# gettting epochs
# process starting for epoch period dates  2 2010-01-01 2011-12-31
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_5 2010-01-01 2011-12-31
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_7 2010-01-01 2011-12-31
# coumputation starts  2016-08-09 16:02:18.499685
# /g/data/v10/public/modules/agdc-py2-env/20160726/envs/agdc/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:326: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# /g/data/v10/public/modules/agdc-py2-env/20160726/envs/agdc/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:1001: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# coumputation finished  2016-08-09 16:09:09.202978
# process completed for epoch 2010-01-01
# process starting for epoch period dates  2 2012-01-01 2013-12-31
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_7 2012-01-01 2013-12-31
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_8 2012-01-01 2013-12-31
# coumputation starts  2016-08-09 16:10:02.310702
# coumputation finished  2016-08-09 16:18:24.377616
# process completed for epoch 2012-01-01
# process starting for epoch period dates  2 2014-01-01 2015-12-03
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_7 2014-01-01 2015-12-03
# Loading data for  WINTER JJA
# Loaded data for  LANDSAT_8 2014-01-01 2015-12-03
# coumputation starts  2016-08-09 16:21:03.151895
# coumputation finished  2016-08-09 16:32:19.507412
# process completed for epoch 2014-01-01
# all process finished
#  do your job with computed data
# 2010-01-01 processing <xarray.DataArray (y: 3073, x: 1297)>
# array([[ 0.34786791,  0.39805827,  0.42611414, ...,  0.32068607,
#          0.26777089,  0.26883721],
#        [ 0.33073696,  0.37094501,  0.41609332, ...,  0.30443099,
#          0.311719  ,  0.28320801],
#        [ 0.30632553,  0.32753164,  0.3824853 , ...,  0.29894996,
#          0.29491526,  0.28153566],
#        ...,
#        [ 0.70980787,  0.70037109,  0.72853184, ...,  0.3500931 ,
#          0.35148364,  0.37602383],
#        [ 0.68890852,  0.70037109,  0.73232323, ...,  0.34691536,
#          0.36086825,  0.34324414],
#        [ 0.68886817,  0.70037109,  0.72119939, ...,  0.38113448,
#          0.35428402,  0.36297375]], dtype=float32)
# Coordinates:
#   * y        (y) float64 -3.936e+06 -3.936e+06 -3.936e+06 -3.936e+06 ...
#   * x        (x) float64 1.532e+06 1.532e+06 1.532e+06 1.532e+06 1.532e+06 ...
#  do your job with computed data
# 2012-01-01 processing <xarray.DataArray (y: 3073, x: 1297)>
# array([[ 0.35710698,  0.42749706,  0.48629531, ...,  0.27953517,
#          0.27210248,  0.28035191],
#        [ 0.31815529,  0.4634378 ,  0.56270283, ...,  0.27885783,
#          0.27401018,  0.29407436],
#        [ 0.37769619,  0.43369734,  0.5027408 , ...,  0.27377191,
#          0.29796204,  0.32905406],
#        ...,
#        [ 0.66696668,  0.68866169,  0.71126437, ...,  0.35382926,
#          0.35047185,  0.37162161],
#        [ 0.67454797,  0.6891892 ,  0.70544785, ...,  0.28072664,
#          0.34581217,  0.34621906],
#        [ 0.67247099,  0.7105943 ,  0.69919848, ...,  0.33175915,
#          0.35881999,  0.316313  ]], dtype=float32)
# Coordinates:
#   * y        (y) float64 -3.936e+06 -3.936e+06 -3.936e+06 -3.936e+06 ...
#   * x        (x) float64 1.532e+06 1.532e+06 1.532e+06 1.532e+06 1.532e+06 ...
#  waiting thread  <myStats(Thread-15, started 139800073033472)>
#  do your job with computed data
# 2014-01-01 processing <xarray.DataArray (y: 3073, x: 1297)>
# array([[ 0.55089259,  0.54949009,  0.5637967 , ...,  0.4169215 ,
#          0.4114134 ,  0.41255176],
#        [ 0.59228915,  0.56920254,  0.58459598, ...,  0.42866713,
#          0.42388758,  0.41768098],
#        [ 0.55663186,  0.53317863,  0.57121772, ...,  0.41778472,
#          0.40926528,  0.42609811],
#        ...,
#        [ 0.59921801,  0.62676722,  0.62235069, ...,  0.36638764,
#          0.38179094,  0.42208052],
#        [ 0.59276879,  0.63928407,  0.64316964, ...,  0.37569603,
#          0.37164229,  0.37217772],
#        [ 0.60095692,  0.58405417,  0.58826107, ...,  0.39790252,
#          0.40912011,  0.39976463]], dtype=float32)
# Coordinates:
#   * y        (y) float64 -3.936e+06 -3.936e+06 -3.936e+06 -3.936e+06 ...
#   * x        (x) float64 1.532e+06 1.532e+06 1.532e+06 1.532e+06 1.532e+06 ...
# Exiting 1
#  waiting thread  <myStats(Thread-16, started 139800062543616)>
# Exiting 2
#  waiting thread  <myStats(Thread-17, started 139799977522944)>
# Exiting 3
# Exiting Main Thread

# %%
import matplotlib as mat
cmap = mat.colors.ListedColormap(['b', '#ffcc66','#ffffcc' , '#ccff66' , '#2eb82e', '#009933' , '#006600'])
bounds = [-1, 0, 0.1, 0.2, 0.3, 0.5, 0.8, 1]
norm = mat.colors.BoundaryNorm(bounds, cmap.N)
for k in sorted(my_data.iterkeys()):
    #my_data[k].plot(cmap=plt.cm.Blues, levels=8)
    my_data[k].plot(cmap=cmap, norm=norm)
    # plt.colors.BoundaryNorm(bounds, cmap.N)
    plt.title('epoch-'+k)
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
    plt.show()

# %%
for k,v in my_data.iteritems():
    v.isel(y=158).plot()

# %%
sorted(my_data.keys())

# %%
my_data['2000-01-01'].y[:]

# %%
for k in sorted(my_data.iterkeys()):
    my_data[k].plot(cmap=plt.cm.Blues, levels=8)
    plt.title('epoch-'+k)
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
    plt.show()
